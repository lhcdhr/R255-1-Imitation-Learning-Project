# %% [markdown]
# # dependencies
# upload the Reacher-v4 agent to /content/ppo_Reacher-v4.zip

# %%
#!git clone http://github.com/HumanCompatibleAI/imitation
#!pip install -e "/content/imitation[dev]"

# %%
# !pip install gymnasium[mujoco]
# Out:
# Collecting gymnasium[mujoco]
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (4.10.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[mujoco])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting mujoco>=2.3.3 (from gymnasium[mujoco])
#   Downloading mujoco-3.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (2.31.6)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]) (9.4.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (1.7.0)
# Collecting glfw (from mujoco>=2.3.3->gymnasium[mujoco])
#   Downloading glfw-2.7.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (3.1.7)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (6.1.3)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (3.17.0)
# Installing collected packages: glfw, farama-notifications, gymnasium, mujoco
# Successfully installed farama-notifications-0.0.4 glfw-2.7.0 gymnasium-0.29.1 mujoco-3.1.3

# %%
# !pip install imitation
# !pip install seals
# !pip install shimmy
# !pip install git+https://github.com/Stable-Baselines-Team/stable-baselines3-contrib
# Out:
# Collecting imitation
#   Downloading imitation-1.0.0-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.4/216.4 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium[classic-control]~=0.29 in /usr/local/lib/python3.10/dist-packages (from imitation) (0.29.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imitation) (3.7.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imitation) (1.25.2)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from imitation) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from imitation) (4.66.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from imitation) (13.7.1)
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from imitation) (1.2.2)
# Collecting seals~=0.2.1 (from imitation)
#   Downloading seals-0.2.1-py3-none-any.whl (35 kB)
# Collecting stable-baselines3~=2.0 (from imitation)
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 26.4 MB/s eta 0:00:00
# Collecting sacred>=0.8.4 (from imitation)
#   Downloading sacred-0.8.5-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard>=1.14 in /usr/local/lib/python3.10/dist-packages (from imitation) (2.15.2)
# Collecting huggingface-sb3~=3.0 (from imitation)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Collecting optuna>=3.0.1 (from imitation)
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 23.6 MB/s eta 0:00:00
# Collecting datasets>=2.8.0 (from imitation)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.8.0->imitation)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (2.31.0)
# Collecting xxhash (from datasets>=2.8.0->imitation)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.8.0->imitation)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.8.0->imitation) (6.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]~=0.29->imitation) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]~=0.29->imitation) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]~=0.29->imitation) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]~=0.29->imitation) (2.5.2)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3~=3.0->imitation) (1.1.2)
# Collecting alembic>=1.5.0 (from optuna>=3.0.1->imitation)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 29.8 MB/s eta 0:00:00
# Collecting colorlog (from optuna>=3.0.1->imitation)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.0.1->imitation) (2.0.28)
# Collecting docopt<1.0,>=0.3 (from sacred>=0.8.4->imitation)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jsonpickle>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from sacred>=0.8.4->imitation) (3.0.3)
# Collecting munch<5.0,>=2.5 (from sacred>=0.8.4->imitation)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: wrapt<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from sacred>=0.8.4->imitation) (1.14.1)
# Requirement already satisfied: py-cpuinfo>=4.0 in /usr/local/lib/python3.10/dist-packages (from sacred>=0.8.4->imitation) (9.0.0)
# Collecting colorama>=0.4 (from sacred>=0.8.4->imitation)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting GitPython (from sacred>=0.8.4->imitation)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 28.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.2->imitation) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.2->imitation) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.2->imitation) (3.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (1.62.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (3.5.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.14->imitation) (3.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->imitation) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->imitation) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->imitation) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.4.0->imitation)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 73.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.4.0->imitation)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.4.0->imitation)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 88.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.4.0->imitation)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.4.0->imitation)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.4.0->imitation)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.9 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.4.0->imitation)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 30.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.4.0->imitation)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.4.0->imitation)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.4.0->imitation)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.4.0->imitation)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->imitation) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->imitation)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imitation) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imitation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imitation) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imitation) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imitation) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imitation) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imitation) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->imitation) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->imitation) (2.16.1)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0.1->imitation)
#   Downloading Mako-1.3.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.8.0->imitation) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.8.0->imitation) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.8.0->imitation) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.8.0->imitation) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.8.0->imitation) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.8.0->imitation) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.14->imitation) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.14->imitation) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.14->imitation) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=1.14->imitation) (1.4.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->imitation) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.8.0->imitation) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.8.0->imitation) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.8.0->imitation) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.8.0->imitation) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.0.1->imitation) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.14->imitation) (2.1.5)
# Collecting gitdb<5,>=4.0.1 (from GitPython->sacred>=0.8.4->imitation)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.8.0->imitation) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->imitation) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython->sacred>=0.8.4->imitation)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=1.14->imitation) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=1.14->imitation) (3.2.2)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=fc977e66e8fbf52f5a277b791a37b5e5f3201bd856c76c796e287e5f46727899
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt, xxhash, smmap, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, munch, Mako, dill, colorlog, colorama, seals, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, gitdb, alembic, optuna, nvidia-cusolver-cu12, huggingface-sb3, GitPython, sacred, datasets, stable-baselines3, imitation
# Successfully installed GitPython-3.1.42 Mako-1.3.2 alembic-1.13.1 colorama-0.4.6 colorlog-6.8.2 datasets-2.18.0 dill-0.3.8 docopt-0.6.2 gitdb-4.0.11 huggingface-sb3-3.0 imitation-1.0.0 multiprocess-0.70.16 munch-4.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 optuna-3.5.0 sacred-0.8.5 seals-0.2.1 smmap-5.0.1 stable-baselines3-2.2.1 xxhash-3.4.1
# Requirement already satisfied: seals in /usr/local/lib/python3.10/dist-packages (0.2.1)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (from seals) (0.29.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from seals) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->seals) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->seals) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium->seals) (0.0.4)
# Collecting shimmy
#   Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (1.25.2)
# Requirement already satisfied: gymnasium>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (0.29.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy) (0.0.4)
# Installing collected packages: shimmy
# Successfully installed shimmy-1.3.0
# Collecting git+https://github.com/Stable-Baselines-Team/stable-baselines3-contrib
#   Cloning https://github.com/Stable-Baselines-Team/stable-baselines3-contrib to /tmp/pip-req-build-9do0erh7
#   Running command git clone --filter=blob:none --quiet https://github.com/Stable-Baselines-Team/stable-baselines3-contrib /tmp/pip-req-build-9do0erh7
#   Resolved https://github.com/Stable-Baselines-Team/stable-baselines3-contrib to commit 667a789af964578cf65de25d31380566c37d8b4c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting stable-baselines3<3.0,>=2.3.0a4 (from sb3_contrib==2.3.0a4)
#   Downloading stable_baselines3-2.3.0a4-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (2.2.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (12.4.99)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.3.0a4->sb3_contrib==2.3.0a4) (1.3.0)
# Building wheels for collected packages: sb3_contrib
#   Building wheel for sb3_contrib (pyproject.toml) ... done
#   Created wheel for sb3_contrib: filename=sb3_contrib-2.3.0a4-py3-none-any.whl size=80867 sha256=2333b56de432cb052996469e12ac0b1605ca2d7ee525d4fee758373188a313cf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_lcthqrr/wheels/f8/e1/97/7e886248901c65ffe4ff7a9c16bccfbde992692ac10d99ee41
# Successfully built sb3_contrib
# Installing collected packages: stable-baselines3, sb3_contrib
#   Attempting uninstall: stable-baselines3
#     Found existing installation: stable-baselines3 2.2.1
#     Uninstalling stable-baselines3-2.2.1:
#       Successfully uninstalled stable-baselines3-2.2.1
# Successfully installed sb3_contrib-2.3.0a4 stable-baselines3-2.3.0a4

# %% [markdown]
# # environment and expert

# %%
import gymnasium as gym
import imitation
import seals

# %%
import numpy as np
from imitation.policies.serialize import load_policy
from imitation.util.util import make_vec_env
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.algorithms.adversarial.airl import AIRL
from imitation.rewards.reward_nets import BasicShapedRewardNet
from imitation.util.networks import RunningNorm
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
import sb3_contrib
from imitation.data import rollout
SEED = 42

# %%
def make_env_expert_rollouts(n_trajs):
    # Create the environment, load expert policy, and sample trajectories
    # from the expert policy and environment.
    global SEED
    env = make_vec_env(
        "Reacher-v4", # seals:seals/CartPole-v0
        rng=np.random.default_rng(SEED),
        n_envs=1,
        post_wrappers=[
            lambda env, _: RolloutInfoWrapper(env)
        ],  # needed for computing rollouts later
        parallel=True,
    )
    expert = load_policy(
        "ppo",
        path = "/content/ppo_Reacher-v4.zip", #-self-trained Reacher expert
        venv=env,
    )
    rollouts = rollout.rollout(
        expert,
        env,
        rollout.make_sample_until(min_timesteps=50, min_episodes = n_trajs),
        rng=np.random.default_rng(SEED), #The random state to use for sampling trajectories
    )

    return env, expert, rollouts
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def make_PPO_learner_and_trainer(env, expert, rollouts):
    global SEED

    learner_PPO = PPO(
        env=env,
        policy=MlpPolicy,
        batch_size=128,
        #clip_range=0.3,
        #ent_coef= 0.0007566389899529574,
        learning_rate=1e-4, #1.943992487657563e-5
        gae_lambda=0.8,
        max_grad_norm=0.9,
        gamma=0.995,
        n_epochs=10,
        seed=SEED,
    )
    reward_net = BasicShapedRewardNet(
        observation_space=env.observation_space,
        action_space=env.action_space,
        normalize_input_layer=RunningNorm,
    )
    airl_trainer = AIRL(
        demonstrations = rollouts, # expert trajectories
        demo_batch_size = 50,
        gen_replay_buffer_capacity = 16384,
        n_disc_updates_per_round = 8, #
        venv = env,
        gen_algo = learner_PPO,
        reward_net=reward_net,
        allow_variable_horizon=True,
        # gen_train_timesteps = 1000
        init_tensorboard=True,
        init_tensorboard_graph=True,

    )
    return learner_PPO, airl_trainer

# %% [markdown]
# # AIRL-PPO 1 trajectory

# %%
env_1, expert_1, rollouts_1 = make_env_expert_rollouts(1)

# %%
learner_PPO_1, airl_trainer_PPO_1 = make_PPO_learner_and_trainer(env_1, expert_1, rollouts_1)
# Out:
# Running with `allow_variable_horizon` set to True. Some algorithms are biased towards shorter or longer episodes, which may significantly confound results. Additionally, even unbiased algorithms can exploit the information leak from the termination condition, producing spuriously high performance. See https://imitation.readthedocs.io/en/latest/getting-started/variable-horizon.html for more information.
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
expert_reward, _ = evaluate_policy(
    expert_1, env_1, 20, return_episode_rewards=True
)
print(
    "expert rewards after training:",
    np.mean(expert_reward),
    "+/-",
    np.std(expert_reward),
)
# Out:
# expert rewards after training: -5.0036284 +/- 1.6795412761026864

# %%
env_1.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner_PPO_1, env_1, 20, return_episode_rewards=True
)

# %%
airl_trainer_PPO_1.train(600000)
# An upper bound on the number of transitions to sample from the environment during training.
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
env_1.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner_PPO_1, env_1, 20, return_episode_rewards=True
)

# %%
print(
    "Rewards before training:",
    np.mean(learner_rewards_before_training),
    "+/-",
    np.std(learner_rewards_before_training),
)
print(
    "Rewards after training:",
    np.mean(learner_rewards_after_training),
    "+/-",
    np.std(learner_rewards_after_training),
)
# Out:
# Rewards before training: -12.0647763 +/- 4.1092375105641334
# Rewards after training: -10.0422026 +/- 4.3535134598608325

# %% [markdown]
# # AIRL-PPO 4 trajectory

# %%
env_4, expert_4, rollouts_4 = make_env_expert_rollouts(4)
learner_PPO_4, airl_trainer_PPO_4 = make_PPO_learner_and_trainer(env_4, expert_4, rollouts_4)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Running with `allow_variable_horizon` set to True. Some algorithms are biased towards shorter or longer episodes, which may significantly confound results. Additionally, even unbiased algorithms can exploit the information leak from the termination condition, producing spuriously high performance. See https://imitation.readthedocs.io/en/latest/getting-started/variable-horizon.html for more information.

# %%
expert_reward, _ = evaluate_policy(
    expert_4, env_4, 20, return_episode_rewards=True
)
print(
    "expert rewards after training:",
    np.mean(expert_reward),
    "+/-",
    np.std(expert_reward),
)
# Out:
# expert rewards after training: -5.0036284 +/- 1.6795412761026864

# %%
env_4.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner_PPO_4, env_4, 20, return_episode_rewards=True
)

# %%
airl_trainer_PPO_4.train(600000) # 1000000
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
env_4.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner_PPO_4, env_4, 20, return_episode_rewards=True
)

# %%
print(
    "learner rewards before training:",
    np.mean(learner_rewards_before_training),
    "+/-",
    np.std(learner_rewards_before_training),
)

print(
    "learner rewards after training:",
    np.mean(learner_rewards_after_training),
    "+/-",
    np.std(learner_rewards_after_training),
)
# Out:
# learner rewards before training: -12.0647763 +/- 4.1092375105641334
# learner rewards after training: -7.334322499999999 +/- 3.3166374029458434

# %% [markdown]
# # AIRL-PPO 10 trajectory

# %%
env_10, expert_10, rollouts_10 = make_env_expert_rollouts(10)
learner_PPO_10, airl_trainer_PPO_10 = make_PPO_learner_and_trainer(env_10, expert_10, rollouts_10)
# Out:
# Running with `allow_variable_horizon` set to True. Some algorithms are biased towards shorter or longer episodes, which may significantly confound results. Additionally, even unbiased algorithms can exploit the information leak from the termination condition, producing spuriously high performance. See https://imitation.readthedocs.io/en/latest/getting-started/variable-horizon.html for more information.

# %%
print(rollouts_10.count)
# Out:
# <built-in method count of list object at 0x7d5dd206fdc0>

# %%
expert_reward, _ = evaluate_policy(
    expert_10, env_10, 20, return_episode_rewards=True
)
print(
    "expert rewards after training:",
    np.mean(expert_reward),
    "+/-",
    np.std(expert_reward),
)
# Out:
# expert rewards after training: -5.0036284 +/- 1.6795412761026864

# %%
env_10.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner_PPO_10, env_10, 20, return_episode_rewards=True
)

# %%
airl_trainer_PPO_10.train(600000) #进度条显示的是gen_train_timestep除以这里的input
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
env_10.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner_PPO_10, env_10, 20, return_episode_rewards=True
)

# %%
print(
    "learner rewards before training:",
    np.mean(learner_rewards_before_training),
    "+/-",
    np.std(learner_rewards_before_training),
)

print(
    "learner rewards after training:",
    np.mean(learner_rewards_after_training),
    "+/-",
    np.std(learner_rewards_after_training),
)
# Out:
# learner rewards before training: -12.0647763 +/- 4.1092375105641334
# learner rewards after training: -8.8860108 +/- 3.726087403806003
